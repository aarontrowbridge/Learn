# %% [markdown]
# Had to install google-auth for some reason even though it comes preloaded, version was outdated and this was the only fix

# %%
# !pip install google-auth
# !pip install --upgrade -q gspread
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# %% [markdown]
# Import Google Sheet

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open('data-1590155268852').sheet1

# get_all_values gives a list of rows.
# 2d array use loops to grab values

rows = worksheet.get_all_values()
print(rows[1][0])


# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# 3460
#         0  ...                                                 16
# 0     pid  ...                                            geocode
# 1    3460  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# 2    3891  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# 3    3478  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# 4    3846  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# ..    ...  ...                                                ...
# 560  3883  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# 561  3798  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# 562  3571  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# 563  3453  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
# 564  2890  ...  {"info":{"statuscode":0,"copyright":{"text":"\...
#
# [565 rows x 17 columns]
